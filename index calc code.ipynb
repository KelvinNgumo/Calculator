# %% [markdown]
# # ******** LIST OF OPERATORS USED ********
#
# 1. Addition (+)
# 2. Subtraction (-)
# 3. Multiplication (*)
# 4. Division (/)
# 5. Floor Division (//) # Rounds down to the nearest whole number
# 6. Modulus (%) # Returns the remainder of a division operation

# %%
print('1. Addition')
print('2. Subtraction') 
print('3. Multiplication')
print('4. Division')
print('5. Floor Division')
Print('6. Modulus')

option = int(input('Select an operator to perform:'))

if option in (1, 2, 3, 4, 5, 6):


else:
    print('Invalid Operator Selected')

# %% [markdown]
# print
